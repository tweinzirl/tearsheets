# %% [markdown]
# ## IBM examples

# %%
# !pip install --upgrade setuptools
# !pip install python-dotenv
# !pip install ibm-generative-ai==0.1.19
# Out:
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (68.0.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Collecting ibm-generative-ai==0.1.19
#   Downloading ibm_generative_ai-0.1.19-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<2 in /usr/local/lib/python3.10/dist-packages (from ibm-generative-ai==0.1.19) (1.26.16)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from ibm-generative-ai==0.1.19) (2.31.0)
# Requirement already satisfied: pydantic<=1.10.10 in /usr/local/lib/python3.10/dist-packages (from ibm-generative-ai==0.1.19) (1.10.10)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ibm-generative-ai==0.1.19) (1.0.0)
# Requirement already satisfied: aiohttp>=3.8.4 in /usr/local/lib/python3.10/dist-packages (from ibm-generative-ai==0.1.19) (3.8.5)
# Requirement already satisfied: pyyaml>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ibm-generative-ai==0.1.19) (6.0.1)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from ibm-generative-ai==0.1.19) (0.24.1)
# Requirement already satisfied: aiolimiter>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from ibm-generative-ai==0.1.19) (1.1.0)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from ibm-generative-ai==0.1.19) (4.65.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.4->ibm-generative-ai==0.1.19) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.4->ibm-generative-ai==0.1.19) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.4->ibm-generative-ai==0.1.19) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.4->ibm-generative-ai==0.1.19) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.4->ibm-generative-ai==0.1.19) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.4->ibm-generative-ai==0.1.19) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.4->ibm-generative-ai==0.1.19) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->ibm-generative-ai==0.1.19) (2023.7.22)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->ibm-generative-ai==0.1.19) (0.17.3)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->ibm-generative-ai==0.1.19) (3.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->ibm-generative-ai==0.1.19) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<=1.10.10->ibm-generative-ai==0.1.19) (4.7.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx>=0.24.1->ibm-generative-ai==0.1.19) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx>=0.24.1->ibm-generative-ai==0.1.19) (3.7.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->httpcore<0.18.0,>=0.15.0->httpx>=0.24.1->ibm-generative-ai==0.1.19) (1.1.2)
# Installing collected packages: ibm-generative-ai
#   Attempting uninstall: ibm-generative-ai
#     Found existing installation: ibm-generative-ai 0.2.4
#     Uninstalling ibm-generative-ai-0.2.4:
#       Successfully uninstalled ibm-generative-ai-0.2.4
# Successfully installed ibm-generative-ai-0.1.19

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
load_dotenv?

# %%
import time, os
from dotenv import load_dotenv
from genai.credentials import Credentials
from genai.model import Model
from genai.schemas import GenerateParams, ModelType

load_dotenv('drive/MyDrive/llm_auth/.env')
api_key = os.getenv("GENAI_KEY", None)
api_url = os.getenv("GENAI_API", None)
creds = Credentials(api_key, api_endpoint=api_url)

# %% [markdown]
# ### Example 1: Generated text between two chatbots
#  - Updated to put limit on text exchange

# %%
print("\n------------- Example (Model Talk)-------------\n")

bob_params = GenerateParams(decoding_method="sample", max_new_tokens=25, temperature=1)
alice_params = GenerateParams(decoding_method="sample", max_new_tokens=45, temperature=0)
bob = Model(ModelType.FLAN_UL2, params=bob_params, credentials=creds)
alice = Model(ModelType.FLAN_T5, params=alice_params, credentials=creds)

count = 0
sentence = "Hello! How are you?"

print(f"[Alice] --> {sentence}")
while count < 7:
    bob_response = bob.generate([sentence])
    # from first batch get first result generated text
    bob_gen = bob_response[0].generated_text
    print(f"[Bob] --> {bob_gen}")

    alice_response = alice.generate([bob_gen])
    # from first batch get first result generated text
    alice_gen = alice_response[0].generated_text
    print(f"[Alice] --> {alice_gen}")

    sentence = alice_gen
    count += 1
    time.sleep(0.5)
# Out:
# ------------- Example (Model Talk)-------------
#
# [Alice] --> Hello! How are you?
# WARNING:genai.schemas.responses:Extra fields missing from GenerateResponse. Add Optional[Type] typing for these fields: {'id'}
# [Bob] --> Great, is there anything you could help me with?
# WARNING:genai.schemas.responses:Extra fields missing from GenerateResponse. Add Optional[Type] typing for these fields: {'id'}
# [Alice] --> No, what can I do?
# WARNING:genai.schemas.responses:Extra fields missing from GenerateResponse. Add Optional[Type] typing for these fields: {'id'}
# [Bob] --> start drawing on the wall
# WARNING:genai.schemas.responses:Extra fields missing from GenerateResponse. Add Optional[Type] typing for these fields: {'id'}
# [Alice] --> start touching the walls
# WARNING:genai.schemas.responses:Extra fields missing from GenerateResponse. Add Optional[Type] typing for these fields: {'id'}
# [Bob] --> (9)
# WARNING:genai.schemas.responses:Extra fields missing from GenerateResponse. Add Optional[Type] typing for these fields: {'id'}
# [Alice] --> (3) L.R.C. 3518(3)(9) Coudraky partnered, in the Caribbean, with ______________________________ ("John Coudraky I") Assuming he retired
# WARNING:genai.schemas.responses:Extra fields missing from GenerateResponse. Add Optional[Type] typing for these fields: {'id'}
# [Bob] --> Writings (Hamber Exhibits)
# WARNING:genai.schemas.responses:Extra fields missing from GenerateResponse. Add Optional[Type] typing for these fields: {'id'}
# [Alice] --> Incorporating the best work of music theoretical authors, this comprehensive millennium celebration of the musical traditions which has helped shape its history also offers a stage for some of our most important composers at the T
# WARNING:genai.schemas.responses:Extra fields missing from GenerateResponse. Add Optional[Type] typing for these fields: {'id'}
# [Bob] --> Tnu lvella Mountain for young music performers, presenting the continuous development of our country
# WARNING:genai.schemas.responses:Extra fields missing from GenerateResponse. Add Optional[Type] typing for these fields: {'id'}
# [Alice] --> and the new formats of performing entertainment events, brings together today's most important system and collaborating with society and individual groups , educate audience for the power of jazz , promoting the role of the young generation of
# WARNING:genai.schemas.responses:Extra fields missing from GenerateResponse. Add Optional[Type] typing for these fields: {'id'}
# [Bob] --> Jazz , Fashion Jazz and New Formats Jazz Festival enlivens many geographical parts of the country and outside,
# WARNING:genai.schemas.responses:Extra fields missing from GenerateResponse. Add Optional[Type] typing for these fields: {'id'}
# [Alice] --> U rekord festival, Masters of Jazz, Jazz Cates, Carlton, Germinal elenceve and many am Bitip but these figures had rekord festival that submits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-7539c836465e> in <cell line: 12>()
#      11 print(f"[Alice] --> {sentence}")
#      12 while count < 7:
# ---> 13     bob_response = bob.generate([sentence])
#      14     # from first batch get first result generated text
#      15     bob_gen = bob_response[0].generated_text
#
# /usr/local/lib/python3.10/dist-packages/genai/model.py in generate(self, prompts, options)
#     131             list[GenerateResult]: A list of results
#     132         """
# --> 133         return list(self.generate_as_completed(prompts, options))
#     134
#     135     def generate_async(
#
# /usr/local/lib/python3.10/dist-packages/genai/model.py in generate_as_completed(self, prompts, options)
#      96         try:
#      97             for i in range(0, len(prompts), Metadata.DEFAULT_MAX_PROMPTS):
# ---> 98                 response_gen = self.service.generate(
#      99                     model=self.model,
#     100                     inputs=prompts[i : min(i + Metadata.DEFAULT_MAX_PROMPTS, len(prompts))],
#
# /usr/local/lib/python3.10/dist-packages/genai/services/service_interface.py in generate(self, model, inputs, params, streaming, options)
#      44             params = ServiceInterface._sanitize_params(params)
#      45             endpoint = self.service_url + ServiceInterface.GENERATE
# ---> 46             return RequestHandler.post(
#      47                 endpoint,
#      48                 key=self.key,
#
# /usr/local/lib/python3.10/dist-packages/genai/services/request_handler.py in post(endpoint, key, model_id, inputs, parameters, streaming, options)
#     235         else:
#     236             with httpx.Client(timeout=ConnectionManager.TIMEOUT) as s:
# --> 237                 response = s.post(url=endpoint, headers=headers, json=json_data)
#     238                 return response
#     239
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in post(self, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1130         **Parameters**: See `httpx.request`.
#    1131         """
# -> 1132         return self.request(
#    1133             "POST",
#    1134             url,
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812             extensions=extensions,
#     813         )
# --> 814         return self.send(request, auth=auth, follow_redirects=follow_redirects)
#     815
#     816     @contextmanager
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     899         auth = self._build_request_auth(request, auth)
#     900
# --> 901         response = self._send_handling_auth(
#     902             request,
#     903             auth=auth,
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     927
#     928             while True:
# --> 929                 response = self._send_handling_redirects(
#     930                     request,
#     931                     follow_redirects=follow_redirects,
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     964                 hook(request)
#     965
# --> 966             response = self._send_single_request(request)
#     967             try:
#     968                 for hook in self._event_hooks["response"]:
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in _send_single_request(self, request)
#    1000
#    1001         with request_context(request=request):
# -> 1002             response = transport.handle_request(request)
#    1003
#    1004         assert isinstance(response.stream, SyncByteStream)
#
# /usr/local/lib/python3.10/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     216         )
#     217         with map_httpcore_exceptions():
# --> 218             resp = self._pool.handle_request(req)
#     219
#     220         assert isinstance(resp.stream, typing.Iterable)
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     260                 with ShieldCancellation():
#     261                     self.response_closed(status)
# --> 262                 raise exc
#     263             else:
#     264                 break
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     243
#     244             try:
# --> 245                 response = connection.handle_request(request)
#     246             except ConnectionNotAvailable:
#     247                 # The ConnectionNotAvailable exception is a special case, that
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      94                 raise ConnectionNotAvailable()
#      95
# ---> 96         return self._connection.handle_request(request)
#      97
#      98     def _connect(self, request: Request) -> NetworkStream:
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     119                 with Trace("response_closed", logger, request) as trace:
#     120                     self._response_closed()
# --> 121             raise exc
#     122
#     123     # Sending the request...
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#      97                     reason_phrase,
#      98                     headers,
# ---> 99                 ) = self._receive_response_headers(**kwargs)
#     100                 trace.return_value = (
#     101                     http_version,
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/http11.py in _receive_response_headers(self, request)
#     162
#     163         while True:
# --> 164             event = self._receive_event(timeout=timeout)
#     165             if isinstance(event, h11.Response):
#     166                 break
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     198
#     199             if event is h11.NEED_DATA:
# --> 200                 data = self._network_stream.read(
#     201                     self.READ_NUM_BYTES, timeout=timeout
#     202                 )
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_backends/sync.py in read(self, max_bytes, timeout)
#      26         with map_exceptions(exc_map):
#      27             self._sock.settimeout(timeout)
# ---> 28             return self._sock.recv(max_bytes)
#      29
#      30     def write(self, buffer: bytes, timeout: typing.Optional[float] = None) -> None:
#
# /usr/lib/python3.10/ssl.py in recv(self, buflen, flags)
#    1257                     "non-zero flags not allowed in calls to recv() on %s" %
#    1258                     self.__class__)
# -> 1259             return self.read(buflen)
#    1260         else:
#    1261             return super().recv(buflen, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1130                 return self._sslobj.read(len, buffer)
#    1131             else:
# -> 1132                 return self._sslobj.read(len)
#    1133         except SSLError as x:
#    1134             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
bob_response
# Out:
# [GenerateResult(generated_text='It took several minutes for the waitress to take our order, then to bring it. Unfortunately, then food took over 40', generated_token_count=25, input_token_count=30, stop_reason='MAX_TOKENS', generated_tokens=None, input_text='It took a long time to get to the buffet, even when we arrived early. I was disappointed with the quality of the food served.', seed=4285672223)]

# %%
alice.generate(['please count to 10 slowly in steps of 2. output result as a python list'])
# Out:
# [GenerateResult(generated_text='a=2 b=2 c=2 d=2 aw=2 bbw=2 camw=2 count=2 while(aw=b and ', generated_token_count=45, input_token_count=21, stop_reason='MAX_TOKENS', generated_tokens=None, input_text='please count to 10 slowly in steps of 2. output result as a python list', seed=2916260101)]

# %%
responses = bob.generate_as_completed(['this is a sentence', 'this is another sentence'])
for response in responses:
    print(f"Generated text: {response}")
# Out:
# Generated text: generated_text='A motorcycle driver swerved into another driver lane who then sped up from fear.' generated_token_count=23 input_token_count=6 stop_reason='EOS_TOKEN' generated_tokens=None input_text='this is a sentence' seed=881481999
# Generated text: generated_text='As the anchovy swam in the water the whales approached to meet him' generated_token_count=21 input_token_count=5 stop_reason='EOS_TOKEN' generated_tokens=None input_text='this is another sentence' seed=2469003477

# %%
responses = bob.generate_as_completed([' \ '.join(['this is a sentence', 'what say you'])])
for response in responses:
    print(f"Generated text: {response}")
# Out:
# Generated text: generated_text='What say you, Zed?' generated_token_count=8 input_token_count=11 stop_reason='EOS_TOKEN' generated_tokens=None input_text='this is a sentence \\ what say you' seed=3708855024

# %%
bob.generate_as_completed?
# Out:
# Signature:
# bob.generate_as_completed(
#     prompts: Union[list[str], list[genai.prompt_pattern.PromptPattern]],
# ) -> collections.abc.Generator[genai.schemas.responses.GenerateResponse]
# Docstring:
# The generate endpoint is the centerpiece of the GENAI alpha.
# It provides a simplified and flexible, yet powerful interface to the supported
# models as a service. Given a text prompt as inputs, and required parameters
# the selected model (model_id) will generate a completion text as generated_text.
#
# Args:
#     prompts (list[str]): The list of one or more prompt strings.
#
# Yields:
#     Generator[GenerateResult]: A generator of results
# File:      ~/venv/llm/lib/python3.11/site-packages/genai/model.py
# Type:      method
